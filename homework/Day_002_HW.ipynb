# %% [markdown]
# ## [作業目標]
# 了解機器學習適合應用的領域與範疇。

# %% [markdown]
# ## [作業重點]
# 透過瞭解機器學習的運作方式，找出非常適用機器學習應用的領域及其原因

# %% [markdown]
# ## 作業
# 請找出一個你認為機器學習可以發光發熱的領域並闡述原因?

# %%
   以現階段科技的發展而言，機器學習在影像辨識上面已經有極大的突破，像是人臉辨識系統(也不限於人臉，可用於很多種物種的外貌分辨)。
我覺得在未來，機器學習在聲控的領域可以越做越好，當收集了越來越多的訊息模組之後，有機會可以做到無異於一般對話之對話機器人，
或是使用於教育界，當學生提出問題時，機器可以透過分析了解學生的癥結點所在，並且透過solution帶給學生更好的學習效果。
除了聲控以外，最近新興的腦波分析也可以透過機器學習處理更大量的腦波資訊，希望可以透過資料分析帶給科技新一步的突破。
對於工程方面，機器學習可以搭配影像學習達到很多的應用，例如使用於自行機器人上，透過monitor的畫面分析，可以給予不同的動作指令，活化自走機
器人的活動，增進其效益。
至於財務金融方面的分析，機器學習所能做到的可能就比較有限，大部分能做到的分析可能都只能預測比較長波段的波動，對於極短時間內(一周內)的變化
機器的分析不一定能夠預測，畢竟影響金融市場的因素太多，不只經濟因素有影響，各國的政治問題也會影響金融市場的波動，因此機器學習在金融市場的
應用可能並不是這麼的好發展(當然透過機器學習，可以在金融市場的大數量標的中，先篩選出小部分標的，也可以透過機器學習去分析價格波動，比對其
他相似的標的去分析其組成預測長期價值或是避免走跌、即將泡沫的標的以達到避險的作用)
PS作答依據由個人專業領域及興趣領域為出發點，ML之運用並不止於此
